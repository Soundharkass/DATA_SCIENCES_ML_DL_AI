# %% [markdown]
# # SUPPORT VECTOR MACHINE (SVM)

# %% [markdown]
# ## Support Vector machine (SVM):
#
# - Support Vector Machine (SVM) is a supervised machine learning algorithm used for classification and regression tasks, though it is more commonly applied to classification problems.
#
# ### Core Idea
# > * SVM tries to find the optimal hyperplane that separates data points of different classes with the maximum margin.
#
# ### **Hyperplane:** A decision boundary that separates different classes.
# ### **Support Vectors:** Data points closest to the hyperplane that influence its position and orientation.
# ### **Margin:** The distance between the hyperplane and the nearest data points from each class. SVM maximizes this margin.
#
#
# ### Types of SVM
#
# > * Linear SVM – Works when data is linearly separable.
# > * Non-linear SVM – Uses kernel functions to transform data into higher dimensions where it becomes linearly separable.
#
#
# ### Common Kernel Functions
#
# > * ### **Linear Kernel:** K(x,y)=x⋅yK(x, y) = x \cdot yK(x,y)=x⋅y
# > * ### **Polynomial Kernel:** K(x,y)=(γx⋅y+r)dK(x, y) = (\gamma x \cdot y + r)^dK(x,y)=(γx⋅y+r)d
# > * ### **Radial Basis Function (RBF):** K(x,y)=e−γ∣∣x−y∣∣2K(x, y) = e^{-\gamma ||x-y||^2}K(x,y)=e−γ∣∣x−y∣∣2
# > * ### **Sigmoid Kernel:** K(x,y)=tanh⁡(γx⋅y+r)K(x, y) = \tanh(\gamma x \cdot y + r)K(x,y)=tanh(γx⋅y+r)
#
#
# ### Advantages
#
# > * Works well for high-dimensional data.
# > * Effective when the number of features is greater than the number of samples.
# > * Robust to overfitting (especially with proper regularization).
#
#
# ### Disadvantages
#
# > * Computationally expensive for large datasets.
# > * Choice of kernel and parameters is crucial.
# > * Less effective when classes overlap significantly.
#
#
# Python Example: SVM Classification
# Pythonimport numpy as np
# from sklearn import datasets
# from sklearn.model_selection import train_test_split
# from sklearn.svm import SVC
# from sklearn.metrics import classification_report, accuracy_score
#
# ### Load dataset (Iris dataset)
# iris = datasets.load_iris()
# X = iris.data
# y = iris.target
#
# ### Split into train and test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# ### Create SVM model with RBF kernel
# model = SVC(kernel='rbf', C=1.0, gamma='scale')
#
# ### Train the model
# model.fit(X_train, y_train)
#
# ### Make predictions
# y_pred = model.predict(X_test)
#
# ### Evaluate the model
# print("Accuracy:", accuracy_score(y_test, y_pred)),
# print("\nClassification Report:\n", classification_report(y_test, y_pred))
#
#
# ### ✅ Key Parameters in SVM:
#
# > * **C:** Regularization parameter (controls trade-off between margin size and classification error).
# > * **kernel:** Type of kernel function (linear, poly, rbf, sigmoid).
# > * **gamma:** Defines influence of a single training example (for RBF/poly/sigmoid kernels).

# %% [markdown]
# ## PROBLEM STATEMENT

# %% [markdown]
# ## 📝 Problem Statement
#
#  * Wine quality assessment is traditionally performed by expert tasters, which is subjective, time-consuming, and costly. With the increasing demand for automated quality control in the wine industry, there is a need for a reliable machine learning model that can classify wine quality based on measurable physicochemical properties.
#
#  * The given dataset contains features such as **fixed acidity, residual sugar, alcohol content, and density**, along with a categorical label indicating wine quality (**High, Medium, Low**).
#
#  * The problem is to **develop a Support Vector Machine (SVM) classification model** that can accurately predict the wine quality label from the provided features. The model should:
#     >  - Handle multiclass classification (High, Medium, Low).
#     >  - Identify the most influential features affecting wine quality.
#     >  - Achieve high accuracy and generalization for unseen data.

# %% [markdown]
# ## DATA COLLECTION

# %% [markdown]
# ## 📊 Data Collection
#
# * The dataset used for this project was collected from a **wine quality classification source**, where each wine sample is described by measurable physicochemical properties. These properties were recorded during wine production and laboratory testing. The dataset contains several hundred entries, each representing a unique wine sample.
#
# ### 🔹 Features Collected
# - **Fixed Acidity** – concentration of non-volatile acids.
# - **Residual Sugar** – amount of sugar left after fermentation.
# - **Alcohol** – percentage of alcohol content.
# - **Density** – mass per unit volume of wine.
# - **Quality Label** – categorical target variable (`High`, `Medium`, `Low`).
#
# ### 🔹 Data Characteristics
# - **Type:** Structured, tabular dataset (CSV format).
# - **Size:** Hundreds of rows with 4 input features and 1 output label.
# - **Nature:** Multiclass classification problem.
# - **Source:** Provided dataset (uploaded by researcher/student for project work).
#
# ### 🔹 Purpose of Collection
# The data was collected to enable **predictive modeling of wine quality** using machine learning algorithms. By analyzing chemical properties, the model can classify wines into quality categories, reducing reliance on subjective human tasting.

# %% [markdown]
# ## DOMAIN ANALYSIS

# %% [markdown]
# ## 🌐 Domain Analysis:
#
# ### 1. Domain Context
# The project lies in the **Food & Beverage industry**, specifically in **wine production and quality control**. Wine quality is a critical factor for consumer satisfaction, pricing, and brand reputation. Traditionally, quality assessment relies on expert tasters, which introduces subjectivity and inconsistency. Machine learning offers an objective, data-driven approach to classify wine quality based on measurable chemical properties.
#
# ### 2. Problem Domain
# - **Domain:** Predictive Analytics in Food Science.
# - **Sub-domain:** Wine Quality Classification using Machine Learning.
# - **Task Type:** Multiclass classification (High, Medium, Low).
# - **Algorithm Focus:** Support Vector Machines (SVM) for robust classification.
#
# ### 3. Stakeholders
# - **Wine Producers:** Automate quality control, reduce costs.
# - **Retailers:** Predict wine quality for pricing and marketing.
# - **Consumers:** Ensure consistent quality standards.
# - **Researchers/Students:** Apply ML techniques to real-world datasets.
#
# ### 4. Input & Output
# - **Input Features:** Fixed acidity, residual sugar, alcohol, density.
# - **Output:** Wine quality label (`High`, `Medium`, `Low`).
#
# ### 5. Challenges in Domain
# - **Subjectivity in Quality Labels:** Human tasters may differ in judgment.
# - **Non-linear Relationships:** Wine quality depends on complex interactions between features.
# - **Class Imbalance:** Some categories may have fewer samples.
# - **Feature Scaling:** SVM requires normalization for optimal performance.
#
# ### 6. Opportunities
# - **Automation:** Replace manual tasting with predictive models.
# - **Scalability:** Apply to large-scale wine production.
# - **Integration:** Deploy models into dashboards or mobile apps for real-time classification.
# - **Research Expansion:** Extend methodology to other beverages (beer, coffee, etc.).

# %% [markdown]
# ## IMPORTING REQUIRED LIBRARIES

# %%
# 📚 Importing Required Libraries

# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif

# Model - Support Vector Machine
from sklearn.svm import SVC

# Evaluation metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Utility
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## LOADING DATASET:

# %%
# Step 1: Load the CSV file
df = pd.read_csv("wine_quality_classification.csv")

# %%
# Step 2: Inspect the dataset
print("Dataset Shape:", df.shape)   # Rows and columns
print(df.head())                   # First 5 records
print(df.info())                   # Data types and non-null counts
# Out:
# Dataset Shape: (1000, 5)
#    fixed_acidity  residual_sugar  alcohol  density quality_label
# 0            9.3             6.4     13.6   1.0005          high
# 1           11.2             2.0     14.0   0.9912        medium
# 2           11.6             0.9      8.2   0.9935           low
# 3           12.9             6.6     12.7   1.0002           low
# 4           13.9            13.8     10.4   0.9942        medium
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fixed_acidity   1000 non-null   float64
#  1   residual_sugar  1000 non-null   float64
#  2   alcohol         1000 non-null   float64
#  3   density         1000 non-null   float64
#  4   quality_label   1000 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB
# None

# %% [markdown]
# ##  Basic Data Checks

# %%
# 1. Check for missing values
print("Missing values:\n", df.isnull().sum())
print("\n")

# 2. Check for duplicate rows
print("Duplicate rows:", df.duplicated().sum())
print("\n")

# 3. Check data types of each column
print("\nData Types:\n", df.dtypes)
print("\n")

# 4. Check unique values in target column
print("\nUnique Quality Labels:", df['quality_label'].unique())
print("\n")

# 5. Basic statistical summary
print("\nStatistical Summary:\n", df.describe())
print("\n")
# Out:
# Missing values:
#  fixed_acidity     0
# residual_sugar    0
# alcohol           0
# density           0
# quality_label     0
# dtype: int64
#
#
# Duplicate rows: 0
#
#
#
# Data Types:
#  fixed_acidity     float64
# residual_sugar    float64
# alcohol           float64
# density           float64
# quality_label      object
# dtype: object
#
#
#
# Unique Quality Labels: ['high' 'medium' 'low']
#
#
#
# Statistical Summary:
#         fixed_acidity  residual_sugar      alcohol      density
# count    1000.000000      1000.00000  1000.000000  1000.000000
# mean       10.174300         7.69200    11.039900     0.997505
# std         3.452693         4.20892     1.760283     0.004300
# min         4.000000         0.50000     8.000000     0.990000
# 25%         7.100000         4.10000     9.500000     0.993900
# 50%        10.400000         7.55000    11.000000     0.997400
# 75%        13.125000        11.50000    12.600000     1.001200
# ...

# %% [markdown]
# ##  Exploratory Data Analysis (EDA):

# %% [markdown]
# ### 1. Distribution of target labels

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='quality_label', data=df, palette='Set2')
plt.title("Wine Quality Label Distribution")
plt.show();

# %% [markdown]
# ### 2. Pairplot to see feature relationships

# %%
sns.pairplot(df, hue='quality_label', diag_kind='kde', palette='Set1')
plt.show();

# %% [markdown]
# ### 3. Correlation heatmap

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(6,5))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Heatmap (Numeric Features Only)")
plt.show()

# %% [markdown]
# ### 4. Boxplots for feature vs quality

# %%
features = ['fixed_acidity','residual_sugar','alcohol','density']
for col in features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='quality_label', y=col, data=df, palette='Set3')
    plt.title(f"{col} vs Wine Quality")
    plt.show();

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# ### 🔹 What this EDA shows
# - **Label Distribution:** Whether classes (`High`, `Medium`, `Low`) are balanced.
# - **Pairplot:** Relationships between features across classes.
# - **Heatmap:** Correlation between features (alcohol and density often show strong influence).
# - **Boxplots:** How each feature varies across wine quality categories.

# %% [markdown]
# ## FEATURES SELECTION

# %% [markdown]
# ### Step 1: Encode target labels (High, Medium, Low → numeric)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['quality_label_encoded'] = le.fit_transform(df['quality_label'])

# %% [markdown]
# ### Step 2: Separate features and target

# %%
X = df[['fixed_acidity','residual_sugar','alcohol','density']]
y = df['quality_label_encoded']

# %% [markdown]
# ### Step 3: Apply SelectKBest with ANOVA F-test

# %%
selector = SelectKBest(score_func=f_classif, k='all')
fit = selector.fit(X, y)

# %% [markdown]
# ### Step 4: Show feature scores

# %%
feature_scores = pd.DataFrame({
    'Feature': X.columns,
    'Score': fit.scores_
}).sort_values(by='Score', ascending=False)

print(feature_scores)
# Out:
#           Feature     Score
# 2         alcohol  2.883025
# 1  residual_sugar  1.336486
# 0   fixed_acidity  0.654344
# 3         density  0.269735

# %% [markdown]
# # Step 5: Visualize feature importance

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Feature', y='Score', data=feature_scores, palette='viridis')
plt.title("Feature Importance (ANOVA F-test)")
plt.show();

# %% [markdown]
# # 🎯 Feature Selection for Wine Quality Dataset:
# ### 🔹 Expected Outcome
# - You’ll get a **ranking of features** based on their statistical importance in predicting wine quality.
# - Typically, **Alcohol** and **Density** emerge as the strongest predictors, followed by **Residual Sugar** and **Fixed Acidity**.
# - The barplot gives a clear visual of feature importance.

# %% [markdown]
# ## MODEL CREAION

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ### Step 1: Encode target labels (High, Medium, Low → numeric)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['quality_label_encoded'] = le.fit_transform(df['quality_label'])

# %% [markdown]
# ### Step 2: Define features (X) and target (y)

# %%
X = df[['fixed_acidity','residual_sugar','alcohol','density']]
y = df['quality_label_encoded']

# %% [markdown]
# ### Step 3: Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# ### Step 4: Feature Scaling (important for SVM)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Step 5: Create and Train SVM Model

# %%
svm_model = SVC(kernel='rbf', C=1, gamma='scale', random_state=42)
svm_model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1, random_state=42)

# %% [markdown]
# ### Step 6: Predictions

# %%
y_pred = svm_model.predict(X_test_scaled)

# %% [markdown]
# ### Step 7: Evaluation

# %%
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# ✅ Accuracy: 0.37
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.39      0.32      0.35       103
#            1       0.40      0.22      0.28        91
#            2       0.35      0.55      0.43       106
#
#     accuracy                           0.37       300
#    macro avg       0.38      0.36      0.35       300
# weighted avg       0.38      0.37      0.36       300
#
#
# Confusion Matrix:
#  [[33 10 60]
#  [24 20 47]
#  [28 20 58]]

# %% [markdown]
# # 🏗️ Model Creation - Support Vector Machine:
# ### 🔹 Explanation
# - **LabelEncoder:** Converts `High`, `Medium`, `Low` into numeric values.
# - **Train-Test Split:** 70% training, 30% testing, stratified to preserve class balance.
# - **StandardScaler:** Normalizes features (essential for SVM).
# - **SVC (RBF kernel):** Chosen for handling non-linear boundaries.
# - **Evaluation:** Accuracy, classification report, and confusion matrix show model performance.

# %% [markdown]
# ## MODELE EVALUATION

# %% [markdown]
# ### Step 1: Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print("✅ Model Accuracy:", accuracy)
# Out:
# ✅ Model Accuracy: 0.37

# %% [markdown]
# ### Step 2: Classification Report

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=le.classes_))

# %% [markdown]
# ### Step 3: Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %% [markdown]
# ### Step 4: Visualize Confusion Matrix

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - SVM Wine Quality")
plt.show();

# %% [markdown]
# # 📈 Model Evaluation:
# ### 🔹 What this gives you
# - **Accuracy:** Overall percentage of correct predictions.
# - **Classification Report:** Precision, recall, and F1-score for each class (`High`, `Medium`, `Low`).
# - **Confusion Matrix:** Shows how many samples were correctly/incorrectly classified per category, with a heatmap for clarity.

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# ### 📌 Conclusion
#
# Through this workflow, you successfully built a **Support Vector Machine (SVM) model** for breast cancer classification. The process involved:
#
# - **Data Preprocessing:** Cleaning the dataset, handling missing values, scaling features.
# - **Feature Selection:** Identifying the most informative predictors (tumor size, shape, texture).
# - **Balancing with SMOTE:** Addressing class imbalance by generating synthetic samples of the minority class.
# - **Model Training:** Applying SVM with proper scaling to maximize separation between malignant and benign cases.
# - **Evaluation:** Measuring accuracy, precision, recall, and F1-score to validate performance.
